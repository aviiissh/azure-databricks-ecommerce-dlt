# %%
customers_df = (
    spark.read
    .option("header", "true")
    .option("inferSchema", "true")
    .csv(
        "abfss://ecommerceproject@<storage_account>.dfs.core.windows.net/raw/customers_dataset/"
    )
)

customers_df.display()
